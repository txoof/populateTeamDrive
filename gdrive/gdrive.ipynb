# %%
import logging
import oauth2client
import httplib2
import re
import time
from ssl import SSLError
from functools import wraps
# from gdrive.auth import getCredentials
from apiclient import discovery
from apiclient import errors

# %%
class GDriveError(Exception):
    pass

class NetworkError(RuntimeError):
    pass

# %%
def retryer(max_retries=10, timeout=2):
    '''
    Retry on specific network related errors with timeout
    https://pragmaticcoders.com/blog/retrying-exceptions-handling-internet-connection-problems/
    '''
    logger = logging.getLogger(__name__)
    logger.debug('max_retries: {}, timeout: {}'.format(max_retries, timeout))
    def decorator(func):
        @wraps(func)
        def retry(*args, **kwargs):
            network_exceptions= (
            errors.HttpError,
            SSLError
            )
            for i in range(max_retries):
                logger.info('attempt: {}'.format(i))
                try:
                    result = func(*args, **kwargs)
                except network_exceptions:
                    time.sleep(timeout)
                    continue
                else:
                    return result
            else:
                raise NetworkError
        return retry
    return decorator

# %%
# google documentation here:
# https://developers.google.com/apis-explorer/#p/
class googledrive():
    '''
    creates a google drive interface object
    
    Accepts:
    google drive v3 service object: (discover.build('drive', 'v3', credentials = credentials_object)
    
    sets:
        userinfo (dict) - (drive.about.get) all user info
        teamdrives (list of dict) - (drive.teamdrives.list) all available team drives
    
    '''
    def __init__(self, object):
        self.logger =logging.getLogger(__name__)
        if  not isinstance(object, oauth2client.client.OAuth2Credentials):
            self.logger.critical('invalid credential object: oauth2client.client.OAtuth2Credentials expected; {} received'.format(type(object)))

            return(None)
        # create the HTTP interface (not entirely sure how this works)
        self.http = object.authorize(httplib2.Http()) 
    
        # build the api discovery service using the http
        self.service = discovery.build('drive', 'v3', http=self.http, cache_discovery=False)
        
        #self.service = object
        # https://developers.google.com/drive/v3/web/mime-types
        self.mimeTypes = {'audio': 'application/vnd.google-apps.audio',
                          'docs': 'application/vnd.google-apps.document',
                          'drawing': 'application/vnd.google-apps.drawing',
                          'file': 'application/vnd.google-apps.file',
                          'folder': 'application/vnd.google-apps.folder',
                          'forms': 'application/vnd.google-apps.form',
                          'mymaps': 'application/vnd.google-apps.map',
                          'photos': 'application/vnd.google-apps.photo',
                          'slides': 'application/vnd.google-apps.presentation',
                          'scripts': 'application/vnd.google-apps.script',
                          'sites': 'application/vnd.google-apps.sites',
                          'sheets': 'application/vnd.google-apps.spreadsheet',
                          'video': 'application/vnd.google-apps.video'}
        
        # fields to include in partial responses
        # https://developers.google.com/apis-explorer/#p/drive/v3/drive.files.create
        self.fields = ['id', 'parents', 'mimeType', 'webViewLink', 'size', 'createdTime', 'trashed', 'kind', 'name',
                      'capabilities', 'owners', 'permissions', 'files', ''] # '' is placeholder for none
    
        self.getuserinfo()
        self.listTeamDrives()

    
    @property
    def types(self):
        '''
        Display supported mimeTypes
        '''
        print('supported mime types:')
        for key in self.mimeTypes:
            #print('%10s: %s' % (key, self.mimeTypes[key]))
            print('{:8} {val}'.format(key+':', val=self.mimeTypes[key]))
    
#     def quote(self, string):
#         '''
#         add double quotes arounda string
#         '''
#         return('"'+str(string)+'"')
    

    def _sanitizeFields(self, fields):
        '''
        Private method for stripping whitespace and unknown field opperators
        accepts:
            fields (string)
        
        returns:
            sanitizedFields (string)'''
        fieldsProcessed=[]
        fieldsUnknown=[]
        myFields = fields.replace(' ','')
        fieldList = re.split(',\s*(?![^()]*\))', myFields)
        # remove whitespace and unknown options
        for each in fieldList:
            if any(each.startswith(i) for i in self.fields):
                fieldsProcessed.append(each)
            else:
                fieldsUnknown.append(each)
        
        return(fieldsProcessed, fieldsUnknown)

    @retryer(max_retries=5)
    def add(self, name = None, mimeType = False, parents = None, 
            fields = 'webViewLink, mimeType, id', sanitize = True):
        '''
        add a file to google drive or team drive:
        NB! when adding to the root of a team drive use the drive ID as the parent

        args:
            name (string): human readable name
            mimeType (string): mimeType (see self.mimeTypes for a complete list)
            parents (list): list of parent folders
            fields (comma separated string): properties to query and return any of the fields listed in 
                self.fields
                see https://developers.google.com/apis-explorer/#p/drive/v3/drive.files.list
            sanitize (bool): remove any field options that are not in the above list - false to allow anything
            
        '''

#         fieldsExpected = self.fields
        fieldsProcessed = []
        fieldsUnknown = []
        body={}
        
        if sanitize:
#             # remove whitespace and unknown options
#             for each in fields.replace(' ','').split(','):
#                 if each in fieldsExpected:
#                     fieldsProcessed.append(each)
#                 else:
#                     fieldsUnknown.append(each)
            fieldsProcessed, fieldsUnknown = self._sanitizeFields(fields)
        else:
            fieldsProcessed = fields.split(',')
            
        if len(fieldsUnknown) > 0:
            self.logger.warn('unrecognized fields: {}'.format(fieldsUnknown))
        
        
        
        if name is None:
            self.logger.error('expected a folder or file name')
            return(False)
        else:
            body['name'] = name
        
        if mimeType in self.mimeTypes:
            self.logger.debug('set mimeType: {}'.format(mimeType))
            body['mimeType'] = self.mimeTypes[mimeType]
        else:
            self.logger.warn('ignoring unknown mimeType: {}'.format(mimeType))
        
        if isinstance(parents, list):
            body['parents'] = parents
        elif parents:
            body['parents'] = [parents]
        self.logger.debug('set parent to: {}'.format(parents))
        self.logger.debug('fields: {}'.format(fieldsProcessed))
        self.logger.debug('body: {}'.format(body))
#         apiString = 'body={}, fields={}'.format(body, ','.join(fieldsProcessed))
#         self.logger.debug('api call: files().create({})'.format(apiString))
        try:
            result = self.service.files().create(supportsTeamDrives=True, body=body, fields=','.join(fieldsProcessed)).execute()
            
        except errors.HttpError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(None)        
        
        return(result)
                
    @retryer(max_retries=5)
    def search(self, name=None, trashed=False, mimeType=False, fuzzy=False, modifiedTime=None, 
               dopperator = '>', parents=None, fields=None, orderBy='createdTime', 
               teamdrive=None, sanitize=True, quiet=True ):
        '''
        search for an item by name and other properties in google drive using drive.files.list
        
        args:
            name (string): item name in google drive - required
            trashed (bool): item is not in trash - default False
            mimeType = (string): item is one of the known mime types (gdrive.mimeTypes) - default None
            fuzzy = (bool): substring search of names in drive
            date = (RFC3339 date string): modification time date string (YYYY-MM-DD)
            dopperator (date comparison opprator string): <, >, =, >=, <=  - default >
            parents = (string): google drive file id string
            orderBy = (comma separated string): order results assending by keys below - default createdTime:
                        'createdTime', 'folder', 'modifiedByMeTime', 
                        'modifiedTime', 'name', 'quotaBytesUsed', 
                        'recency', 'sharedWithMeTime', 'starred', 
                        'viewedByMeTime'
            fields (comma separated string): properties to query and return any of the files(fields) listed in 
                self.fields
                see https://developers.google.com/apis-explorer/#p/drive/v3/drive.files.list
            sanitize (bool): remove any field options that are not in the fields list - false to allow anything
            teamdrive (string): Team Drive ID string - when included only the specified Team Drive is searched
            quiet (bool): false prints all the results
                        
                        
            
        returns:
            list of file dict
        '''
        # see https://developers.google.com/drive/api/v3/search-parameters for full list
        qFeatures = ['name', 'trashed', 'mimeType', 'modifiedTime', 'parents']
        
        # formatting structure for each query feature 
        build = {'name' : 'name {} "{}"'.format(('contains' if fuzzy else '='), name),
                 'trashed' : 'trashed={}'. format(trashed),
                 'mimeType' : 'mimeType="{}"'.format(self.mimeTypes[mimeType] if mimeType in self.mimeTypes else ''),
                 'parents': '"{}" in parents'.format(parents),
                 'modifiedTime': 'modifiedTime{}"{}"'.format(dopperator, modifiedTime)}


        if sanitize and fields:
            fieldsProcessed, fieldsUnknown = self._sanitizeFields(fields)
            # only supporting the files() fields here
            fieldsProcessed = 'files({})'.format(','.join(fieldsProcessed))
        else:
            if fields:
                fieldsProcessed = fields.split(',')
            else:
                fieldsProcessed = 'files'
            fieldsUnknown = ''
            
        if len(fieldsUnknown) > 0:
            self.logger.warn('unrecognized fields: {}'.format(fieldsUnknown))
        # provides for setting trashed to True/False if the input is not None
        if not isinstance(trashed, type(None)):
            # set to true as the variable is now in use, but it's value has been set above
            trashed = True
        
        # list of query opperations
        qList = []

        # evaluate feature options; if they are != None/False, use them in building query
        for each in qFeatures:
            if eval(each):
                qList.append(build[each])
        
        apiString = 'q={}, orderBy={}, fields={})'.format(' and '.join(qList), orderBy, fieldsProcessed)
        self.logger.debug('apicall: files().list({})'.format(apiString))
        
        if not quiet:
            print apiString
        
        try:
            # build a query with "and" statements

            if teamdrive:
                result = self.service.files().list(q=' and '.join(qList), 
                                                   corpora='teamDrive',
                                                   includeTeamDriveItems='true',
                                                   orderBy=orderBy,                                             
                                                   teamDriveId=teamdrive, 
                                                   supportsTeamDrives='true',
                                                   fields=fieldsProcessed).execute()
            else:
                result = self.service.files().list(q=' and '.join(qList), orderBy=orderBy, fields).execute()

        except errors.HttpError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(None)

        return(result)
    
    @retryer(max_retries=5)
    def ls(self, *args, **kwargs):
        '''
        List files in google drive using any of the following properties:
            
        accepts:
            name (string): item name in google drive - required
            trashed (bool): item is not in trash - default None (not used)
            mimeType = (string): item is one of the known mime types (gdrive.mimeTypes) - default None
            fuzzy = (bool): substring search of names in drive
            date = (RFC3339 date string): modification time date string (YYYY-MM-DD)
            dopperator (date comparison opprator string): <, >, =, >=, <=  - default >
            parent = (string): google drive file id string    
        '''
        try:
            result = self.search(*args, **kwargs)
            for eachFile in result.get('files', []):
                print('name: {f[name]}, ID:{f[id]}, mimeType:{f[mimeType]}'.format(f=eachFile))
            
        except GDriveError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(None)
        
        return(result)
            
    
    @retryer(max_retries=5)
    def getprops(self, fileId = None, fields = 'parents, mimeType, webViewLink', sanitize=True):
        '''
        get a file or folder's properties based on google drive fileId
        
        for a more complete list: https://developers.google.com/drive/v3/web/migration
        
        args:
            fileId (string): google drive file ID
            fields (comma separated string): properties to query and return any of the fields
                listed in self.fields
            sanitize (bool): remove any field options that are not in the above list - false to allow anything
            
        returns:
            list of dictionary - google drive file properties
            
        raises GDriveError
        '''
        fieldsExpected = self.fields
        
        fieldsProcessed = []
        fieldsUnknown = []

        # move this into a private method 
        if sanitize:
            fieldsProcessed, fieldsUnknown = self._sanitizeFields(fields)
        else:
            fieldsProcessed = fields.split(',')
        if len(fieldsUnknown) > 0:
            self.logger.error('unrecognized fields: {}'.format(fieldsUnknown))
        
        apiString = 'fileId={}, fields={}'.format(fileId, ','.join(fieldsProcessed))
        self.logger.debug('files().get({})'.format(apiString))
        try:
            result = self.service.files().get(supportsTeamDrives=True, fileId=fileId, fields=','.join(fieldsProcessed)).execute()

        except errors.HttpError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(None)
        
        return(result)
    
    @retryer(max_retries=5)
    def getpermissions(self, fileId):
        """
        get a file, folder or Team Drive's permissions
        """
        self.logger.debug('checking permissions for item id: {}'.format(fileId))
        try:
            permissions = self.service.permissions().list(fileId=fileId, 
                                                          supportsTeamDrives=True).execute()
            
        except (errors.HttpError, error) as e:
            if e.resp.status in [404]:
                self.logger.info('file/folder not found')
                return(None)
            else:
                self.logger.error(e)
                raise GDriveError(e)
        
        return(permissions)
    
    @retryer(max_retries=5)
    def parents(self, fileId):
        # need to update to work with TeamDrive
        """get a file's parents.

        Args:
            fileId: ID of the file to print parents for.
        
        raises GDriveError
        """
        self.logger.debug('checking parents for item id: {}'.format(fileId))
        apiString = 'fileId={}, fields="parents"'.format(fileId)
        self.logger.debug('api call: {}'.format(apiString))
        try:
            parents = self.service.files().get(supportsTeamDrives=True,fileId=fileId, fields='parents').execute()
        except errors.HttpError as e:
            if e.resp.status in [404]:
                self.logger.info('file/folder not found')
                return(None)
            else:
                self.logger.error(e)
                raise GDriveError(e)
        
        return(parents)

    
    def rm(self):
        pass
    
    @retryer(max_retries=5)
    def getuserinfo(self):
        try:
            user = self.service.about().get(fields='user').execute()
        except errors.HttpError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(none)
        
        self.userinfo = user['user']
        return(user['user'])
    
    @retryer(max_retries=5)
    def listTeamDrives(self):
        '''
        List first page of team drives available to the user 
            - this method ignores the continuation token (I can't figure it out!)
            raises GDriveError
            
            returns: 
                dictonary of first page of TeamDrives and capabilities
        '''
        fields = ['teamDrives']
       
        
        try:
            result = self.service.teamdrives().list(fields=','.join(fields)).execute()
        except errors.HttpError as e:
            self.logger.error(e)
            raise GDriveError(e)
            return(None)
        
        self.teamdrives = result['teamDrives']
        return(result['teamDrives'])
    
    
#     def testgetprops(self, fileId = None, fields = 'parents, mimeType, webViewLink', sanitize=True):
#         '''
#         get a file or folder's properties based on google drive fileId
        
#         for a more complete list: https://developers.google.com/drive/v3/web/migration
        
#         args:
#             fileId (string): google drive file ID
#             fields (comma separated string): properties to query and return any of the fields
#                 listed in self.fields
#             sanitize (bool): remove any field options that are not in the above list - false to allow anything
            
#         returns:
#             list of dictionary - google drive file properties
            
#         raises GDriveError
#         '''
#         fieldsExpected = self.fields
        
#         fieldsProcessed = []
#         fieldsUnknown = []

#         # move this into a private method 
#         if sanitize:
#             fieldsProcessed, fieldsUnknown = self._sanitizeFields(fields)
#         else:
#             fieldsProcessed = fields.split(',')
#         if len(fieldsUnknown) > 0:
#             self.logger.error('unrecognized fields: {}'.format(fieldsUnknown))
        
#         apiString = 'fileId={}, fields={}'.format(fileId, ','.join(fieldsProcessed))
#         self.logger.debug('files().get({})'.format(apiString))
#         try:
#             result = self.service.files().get(supportsTeamDrives=True, fileId=fileId, fields=','.join(fieldsProcessed)).execute()

#         except errors.HttpError as e:
#             if e.resp.status in [404]:
#                 self.logger.info('file/folder not found')
#                 return(None)
#             else:
#                 self.logger.error(e)
#                 raise GDriveError(e)
        
#         return(result)

# %%
# # create an instance for testing
from auth import *
logger = logging.getLogger(__name__)
logging.getLogger().setLevel(logging.DEBUG)
credential_store = "/tmp/"
credentials = getCredentials(credential_store)
myDrive = googledrive(credentials)
# Out:
# DEBUG:auth:preparing google drive credentials
# DEBUG:root:checking for credential store directory: /tmp/
# DEBUG:root:credential store accepted
# INFO:googleapiclient.discovery:URL being requested: GET https://www.googleapis.com/discovery/v1/apis/drive/v3/rest
# INFO:__main__:attempt: 0
# INFO:googleapiclient.discovery:URL being requested: GET https://www.googleapis.com/drive/v3/about?fields=user&alt=json
# INFO:__main__:attempt: 0
# INFO:googleapiclient.discovery:URL being requested: GET https://www.googleapis.com/drive/v3/teamdrives?fields=teamDrives&alt=json

# %%
myDrive.service.files().list(q='name contains "Abohaime"', 
                                                   
                                                
                                                   fields=('files')).execute()
# Out:
# INFO:googleapiclient.discovery:URL being requested: GET https://www.googleapis.com/drive/v3/files?q=name+contains+%22Abohaime%22&fields=files&alt=json
# {u'files': [{u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-06-14T13:06:06.379Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0BxetgNAafeY-T2dvd2dQRVNDcVg2bXdjQ2tiUGJJdGp3Qm1JPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1OczQw4RZWisch6SzfhfcAb5iXmv-Yf82',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Sophie Campbell',
#     u'emailAddress': u'scampbell@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'04143704562239146464',
#     u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'},
#    u'md5Checksum': u'61482b7405773ff996384a08aae4d5fc',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-06-14T13:06:06.379Z',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'04143704562239146464',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissionIds': [u'14867985035974787748',
#     u'05732040215785115976',
#     u'13370489768962621746',
#     u'15464616757086997128',
#     u'03847252775599853952',
#     u'03704084252452919985',
#     u'17327368186280741424',
#     u'09557985165015739040',
#     u'17344118116844227639',
#     u'12076036697679222418',
#     u'01904419473150579339',
#     u'14527772036446221810',
#     u'04143704562239146464'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017',
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'id': u'04143704562239146464',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'64569',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/xSQCvh00GINpOoaCDxssl2ot_xDNHsRZD7BGJdBZmAzyS7Lq8m3N13RwWQaBrNtOKtJoHBtrjGs=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'15',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1OczQw4RZWisch6SzfhfcAb5iXmv-Yf82&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1OczQw4RZWisch6SzfhfcAb5iXmv-Yf82/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': False,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': False,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': False,
#     u'canRename': False,
#     u'canShare': False,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-06-14T11:46:22.507Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0B4xsxcaIbyNVUXNhbVRPL1JsVjlHYmxsNGRqMklXbXp5U2lrPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1Mr-Trcv2UAiV9a-6VmmaqrWeT1OuoRgm',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'ASH Upper Elementary School Office',
#     u'emailAddress': u'ueoffice@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'03847252775599853952'},
#    u'md5Checksum': u'61482b7405773ff996384a08aae4d5fc',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-06-14T11:46:22.507Z',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'03847252775599853952'}],
#    u'parents': [u'1HY9BNrdmOwODaqE8-RS9S5UDG1NnznAB'],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'64569',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/yz9LcDiqw5vBxtIEaCKoWLpp5gU56W6iSCvTE2T5tRMRbaift3fez-QtKH-Ompus4tgXPvWRVV4=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'17',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1Mr-Trcv2UAiV9a-6VmmaqrWeT1OuoRgm&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1Mr-Trcv2UAiV9a-6VmmaqrWeT1OuoRgm/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-06-14T09:01:47.464Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0BxetgNAafeY-Q0hnMkhUaXU4WGFaYmN0b1VSVEJFek1zL2FnPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1iQDEgZuNK_RVvGcgz04WRhnAxaN4tSsn',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Sophie Campbell',
#     u'emailAddress': u'scampbell@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'04143704562239146464',
#     u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'},
#    u'md5Checksum': u'7aa97265f3fcbe9632c009adba3ff71d',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-06-14T09:01:47.464Z',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'04143704562239146464',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017',
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'id': u'04143704562239146464',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'97087',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/0CC6AGIbkzDt9dP9x7tv3l1dIrxsyVoLIaODC0TK6_OAPUWELzOIoMg6UAD1X4SiV1ILMYGS2lc=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'17',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1iQDEgZuNK_RVvGcgz04WRhnAxaN4tSsn&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1iQDEgZuNK_RVvGcgz04WRhnAxaN4tSsn/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': False,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': False,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': False,
#     u'canRename': False,
#     u'canShare': False,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-06-13T11:41:15.347Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0B4xsxcaIbyNVVitwZ1d3QnVtazhMa1daRjE0eHhyQ0VGekRnPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1LQoNe-MAHf9AJz_bKKuQdPB8knSUpllc',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'ASH Upper Elementary School Office',
#     u'emailAddress': u'ueoffice@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'03847252775599853952'},
#    u'md5Checksum': u'7aa97265f3fcbe9632c009adba3ff71d',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-06-13T11:41:15.347Z',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'03847252775599853952'}],
#    u'parents': [u'1ByIlSNkXPm1aG0I6OeSwWIhPhS_u_76W'],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'97087',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/SinCJeYfNxZoaukNC6QR9BtfHngaQcJ_aX2WL2ULXhfmTupslp8HcUvtL5mjmoMkwOrGqtVf3kQ=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'16',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1LQoNe-MAHf9AJz_bKKuQdPB8knSUpllc&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1LQoNe-MAHf9AJz_bKKuQdPB8knSUpllc/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-06-07T12:51:35.510Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0BxetgNAafeY-aHB4dkQxTm94WWt1TXlEbmVHTFBzR0JnVmdrPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1eBNmkYhGS4VaKzX6JZwWb5XxE5FH8qih',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Sophie Campbell',
#     u'emailAddress': u'scampbell@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'04143704562239146464',
#     u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'},
#    u'md5Checksum': u'828a3c84b840e39032a2b6c84cfdb786',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-06-07T12:51:35.510Z',
#    u'name': u'Abohaimed, Saud Grade 2 MAP 2017-2018.pdf',
#    u'originalFilename': u'Abohaimed, Saud Grade 2 MAP 2017-2018.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'04143704562239146464',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017',
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'id': u'04143704562239146464',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'118428',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/N8RnlGT6pkPUEyl3DlwTNeQFogogd2oakK0JjNzzyS5v1HBeQHpDD2rkXmJ1DVljBd86ZQn--VA=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'15',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1eBNmkYhGS4VaKzX6JZwWb5XxE5FH8qih&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1eBNmkYhGS4VaKzX6JZwWb5XxE5FH8qih/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-05-16T08:41:53.835Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0BxetgNAafeY-QWtjT2tSL1dMRzNvNmFJR01zV3hJbnVFQ1NZPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'12Pdw_QREiiB5E0NTA9u_7-fIFRNSp3tb',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Sophie Campbell',
#     u'emailAddress': u'scampbell@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'04143704562239146464',
#     u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'},
#    u'md5Checksum': u'cfb424899f415488658bcf4c910d08e7',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-05-16T08:41:53.835Z',
#    u'name': u'Abohaimed, Saud DRA Feb 2018.pdf',
#    u'originalFilename': u'Abohaimed, Saud DRA Feb 2018.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'04143704562239146464',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017',
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'id': u'04143704562239146464',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'843593',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/DfHyzi_3xCPN-c82PtdZhRNVLQ_ne9pK4ffZnXsPFmYmrq33EUWNQgNw5zZuGxssvmWeR0p5x4o=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'25',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=12Pdw_QREiiB5E0NTA9u_7-fIFRNSp3tb&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/12Pdw_QREiiB5E0NTA9u_7-fIFRNSp3tb/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-05-14T09:55:26.653Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0BxetgNAafeY-OWwrQWxlZ1VmRkgrb1gxblZad25PRDlwWkFVPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'15FW8EFK7YiEMVoR1hzlnXUb7RgjKbIQz',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Sophie Campbell',
#     u'emailAddress': u'scampbell@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'04143704562239146464',
#     u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'},
#    u'md5Checksum': u'd3101108dbb47d0fa235d9638a794372',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-05-16T08:33:58.869Z',
#    u'name': u'Abohaimed, Saud Progress Report Q3 2017-2018.pdf',
#    u'originalFilename': u'Abohaimed, Saud Progress Report Q3 2017-2018.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'04143704562239146464',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017',
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Sophie Campbell',
#      u'emailAddress': u'scampbell@ash.nl',
#      u'id': u'04143704562239146464',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-TXBfxxB4u_M/AAAAAAAAAAI/AAAAAAAAAkI/72zOlHWfW6w/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'179896',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/EVIMUw9Igrf7FBwt37d35XuZkuK81MaUzDpS98kNT25JdwkEgkfA8SSoYVBaKb6SVcomsonUEkU=s220',
#    u'thumbnailVersion': u'3',
#    u'trashed': False,
#    u'version': u'32',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=15FW8EFK7YiEMVoR1hzlnXUb7RgjKbIQz&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/15FW8EFK7YiEMVoR1hzlnXUb7RgjKbIQz/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': False,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': False,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': False,
#     u'canRename': False,
#     u'canShare': False,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-04-23T12:22:22.149Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0B4xsxcaIbyNVZExrSkQya1lWaE80akV4UUFnNXBiU25yMnl3PQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1wfitLtTBcgo0ES-8aX1lHUDCyaBGFaQ1',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'ASH Upper Elementary School Office',
#     u'emailAddress': u'ueoffice@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'03847252775599853952'},
#    u'md5Checksum': u'7e701d48e9f9a0f8afc5149a4356abfa',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-04-23T12:22:22.149Z',
#    u'name': u'Saud Abohaimed-503868-1_ASH grade 2 progress report 2017-18.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_ASH grade 2 progress report 2017-18.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'03847252775599853952'}],
#    u'parents': [u'1K3Kp2IaRRHhuXqU38cLeTa_KaTLs8lTF'],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'43357',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/xXEV_WNpZZPB68DNdKiPUDTN0o22MG69AVwSwfKwM0wGUbf4QM2Y_fqUrtchCE20m_FLitFe45o=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'21',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1wfitLtTBcgo0ES-8aX1lHUDCyaBGFaQ1&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1wfitLtTBcgo0ES-8aX1lHUDCyaBGFaQ1/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': False,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': False,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': False,
#     u'canRename': False,
#     u'canShare': False,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-04-23T12:20:47.283Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0B4xsxcaIbyNVUFJkYzhIMWFRWTd4MjNib1hFOVVha3h4TXFZPQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'1GO89kVokPemNCeHKslnj25ErNhUGmQn6',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'ASH Upper Elementary School Office',
#     u'emailAddress': u'ueoffice@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'03847252775599853952'},
#    u'md5Checksum': u'49990a7f0eddf53264ddfb10db905a0f',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-04-23T12:20:47.283Z',
#    u'name': u'Saud Abohaimed-503868-1_ASH grade 2 EAL progress report S2 2017-18.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_ASH grade 2 EAL progress report S2 2017-18.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'03847252775599853952'}],
#    u'parents': [u'1uKtqDh4fruWsK76zhD-HhY2QgqBVpO75'],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'size': u'96260',
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailLink': u'https://lh3.googleusercontent.com/9rO1TfwFcQgle4KITfvi3lUE_oCrPhxhBXEWkU2aojczbzDaK5eIdGKaZMZLQJ-RN1B9moLUd0Q=s220',
#    u'thumbnailVersion': u'1',
#    u'trashed': False,
#    u'version': u'22',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webContentLink': u'https://drive.google.com/a/ash.nl/uc?id=1GO89kVokPemNCeHKslnj25ErNhUGmQn6&export=download',
#    u'webViewLink': u'https://drive.google.com/a/ash.nl/file/d/1GO89kVokPemNCeHKslnj25ErNhUGmQn6/view?usp=drivesdk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': False,
#     u'canChangeCopyRequiresWriterPermission': False,
#     u'canChangeViewersCanCopyContent': False,
#     u'canComment': True,
#     u'canCopy': True,
#     u'canDelete': False,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': False,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': True,
#     u'canRemoveChildren': False,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': False,
#     u'canUntrash': False},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2018-01-26T11:19:42.699Z',
#    u'explicitlyTrashed': False,
#    u'fileExtension': u'pdf',
#    u'fullFileExtension': u'pdf',
#    u'hasThumbnail': True,
#    u'headRevisionId': u'0B4xsxcaIbyNVSExBUEVRU3pnMkg5N1FYenFVNGtzUU1kdjA4PQ',
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/pdf',
#    u'id': u'10bqyHqGQE3cnugWkGMd8HHOlEc7sHk2t',
#    u'isAppAuthorized': False,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'ASH Upper Elementary School Office',
#     u'emailAddress': u'ueoffice@ash.nl',
#     u'kind': u'drive#user',
#     u'me': False,
#     u'permissionId': u'03847252775599853952'},
#    u'md5Checksum': u'2c5ec9dcce6f188599e70d70bd0078b4',
#    u'mimeType': u'application/pdf',
#    u'modifiedByMe': False,
#    u'modifiedTime': u'2018-01-26T11:19:42.699Z',
#    u'name': u'Saud Abohaimed-503868-1_ASH EAL report card grade 2 S1 2017-18.pdf',
#    u'originalFilename': u'Saud Abohaimed-503868-1_ASH EAL report card grade 2 S1 2017-18.pdf',
#    u'ownedByMe': False,
#    u'owners': [{u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'kind': u'drive#user',
#      u'me': False,
#      u'permissionId': u'03847252775599853952'}],
#    u'parents': [u'0B7jrBr-B2fCeTjhXZ0RaVmhPOHc'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Sharon Townshend',
#      u'emailAddress': u'stownshend@ash.nl',
#      u'id': u'05732040215785115976',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-E_EorPhmk2o/AAAAAAAAAAI/AAAAAAAACdo/0s7UBqmjNYo/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Early Childhood Center Office',
#      u'emailAddress': u'eccoffice@ash.nl',
#      u'id': u'15464616757086997128',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-KT89DzzrG-8/AAAAAAAAAAI/AAAAAAAAAus/Fez2lNfNRF8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Tim Messick',
#      u'emailAddress': u'tmessick@ash.nl',
#      u'id': u'17327368186280741424',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-_SSTA1Z1nNI/AAAAAAAAAAI/AAAAAAAAATA/N0DG_f3fWY8/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'TestD 2016/2017 teachers',
#      u'emailAddress': u'TestD_2016_2017_teachers_081c12bd@ash.nl',
#      u'id': u'17344118116844227639',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
# ...
#      u'emailAddress': u'TestD_2016_2017_66e2f48a@ash.nl',
#      u'id': u'14527772036446221810',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'ASH Elementary School Assistant Principal',
#      u'emailAddress': u'esassistantprincipal@ash.nl',
#      u'id': u'13370489768962621746',
#      u'kind': u'drive#permission',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailVersion': u'0',
#    u'trashed': False,
#    u'version': u'761828',
#    u'viewedByMe': True,
#    u'viewedByMeTime': u'2018-05-07T18:52:34.902Z',
#    u'viewersCanCopyContent': True,
#    u'webViewLink': u'https://drive.google.com/drive/folders/0B7jrBr-B2fCedllGZWFvRWJpdEk',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': True,
#     u'canChangeCopyRequiresWriterPermission': True,
#     u'canChangeViewersCanCopyContent': True,
#     u'canComment': True,
#     u'canCopy': False,
#     u'canDelete': True,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': True,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': True,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': True,
#     u'canUntrash': True},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2017-03-22T17:28:44.565Z',
#    u'explicitlyTrashed': False,
#    u'folderColorRgb': u'#8f8f8f',
#    u'hasThumbnail': False,
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder+shared',
#    u'id': u'0B9WTleJ1MzaYdDR1Z1NGeGJFdlU',
#    u'isAppAuthorized': True,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Aaron Ciuffo',
#     u'emailAddress': u'aciuffo@ash.nl',
#     u'kind': u'drive#user',
#     u'me': True,
#     u'permissionId': u'14867985035974787748',
#     u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'},
#    u'mimeType': u'application/vnd.google-apps.folder',
#    u'modifiedByMe': True,
#    u'modifiedByMeTime': u'2017-03-22T17:28:44.565Z',
#    u'modifiedTime': u'2017-03-22T17:28:44.565Z',
#    u'name': u'Abohaimed, Saud - 503868',
#    u'ownedByMe': True,
#    u'owners': [{u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'kind': u'drive#user',
#      u'me': True,
#      u'permissionId': u'14867985035974787748',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'}],
#    u'parents': [u'0B9WTleJ1MzaYRHpWUVVKVnRYUG8'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Bridget Anderson',
#      u'emailAddress': u'banderson@ash.nl',
#      u'id': u'11954340966729335823',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-hNKJazOg37k/AAAAAAAAAAI/AAAAAAAAAEg/sj2zyzRJaHE/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Jasper Kalkman',
#      u'emailAddress': u'jfk@ash.nl',
#      u'id': u'02345238176040770478',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-ExKL7FdCQKg/AAAAAAAAAAI/AAAAAAAAACA/ZqZt4qymvUM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Leadership Team',
#      u'emailAddress': u'leadership-team@ash.nl',
#      u'id': u'00327650590473223628',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'All Staff',
#      u'emailAddress': u'staff@ash.nl',
#      u'id': u'07178977842753512527',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailVersion': u'0',
#    u'trashed': True,
#    u'version': u'696407',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webViewLink': u'https://drive.google.com/drive/folders/0B9WTleJ1MzaYdDR1Z1NGeGJFdlU',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': True,
#     u'canChangeCopyRequiresWriterPermission': True,
#     u'canChangeViewersCanCopyContent': True,
#     u'canComment': True,
#     u'canCopy': False,
#     u'canDelete': True,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': True,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': True,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': True,
#     u'canUntrash': True},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2017-03-20T11:34:28.010Z',
#    u'explicitlyTrashed': False,
#    u'folderColorRgb': u'#8f8f8f',
#    u'hasThumbnail': False,
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder+shared',
#    u'id': u'0B9WTleJ1MzaYSVBuVzRyVUFQT0U',
#    u'isAppAuthorized': True,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Aaron Ciuffo',
#     u'emailAddress': u'aciuffo@ash.nl',
#     u'kind': u'drive#user',
#     u'me': True,
#     u'permissionId': u'14867985035974787748',
#     u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'},
#    u'mimeType': u'application/vnd.google-apps.folder',
#    u'modifiedByMe': True,
#    u'modifiedByMeTime': u'2017-03-20T11:34:28.010Z',
#    u'modifiedTime': u'2017-03-20T11:34:28.010Z',
#    u'name': u'Abohaimed, Saud - 503868',
#    u'ownedByMe': True,
#    u'owners': [{u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'kind': u'drive#user',
#      u'me': True,
#      u'permissionId': u'14867985035974787748',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'}],
#    u'parents': [u'0B9WTleJ1MzaYaUF0NUIxVDhiWlk'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Admin',
#      u'emailAddress': u'aciuffo_adm@ash.nl',
#      u'id': u'09557985165015739040',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh5.googleusercontent.com/-fSQyliAWy-E/AAAAAAAAAAI/AAAAAAAAABE/GPdw0MlXlKM/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'ASH Upper Elementary School Office',
#      u'emailAddress': u'ueoffice@ash.nl',
#      u'id': u'03847252775599853952',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Rachel Mougey',
#      u'emailAddress': u'rmougey@ash.nl',
#      u'id': u'03704084252452919985',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-7akS3yjmbDI/AAAAAAAAAAI/AAAAAAAAAA0/Q3gtXWFmXRA/s64/photo.jpg',
#      u'role': u'writer',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Bridget Anderson',
#      u'emailAddress': u'banderson@ash.nl',
#      u'id': u'11954340966729335823',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-hNKJazOg37k/AAAAAAAAAAI/AAAAAAAAAEg/sj2zyzRJaHE/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Jasper Kalkman',
#      u'emailAddress': u'jfk@ash.nl',
#      u'id': u'02345238176040770478',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh4.googleusercontent.com/-ExKL7FdCQKg/AAAAAAAAAAI/AAAAAAAAACA/ZqZt4qymvUM/s64/photo.jpg',
#      u'role': u'reader',
#      u'type': u'user'},
#     {u'deleted': False,
#      u'displayName': u'Faculty ECC',
#      u'emailAddress': u'ecc_staff@ash.nl',
#      u'id': u'12076036697679222418',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Faculty UE',
#      u'emailAddress': u'ue_staff@ash.nl',
#      u'id': u'01904419473150579339',
#      u'kind': u'drive#permission',
#      u'role': u'writer',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Leadership Team',
#      u'emailAddress': u'leadership-team@ash.nl',
#      u'id': u'00327650590473223628',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'All Staff',
#      u'emailAddress': u'staff@ash.nl',
#      u'id': u'07178977842753512527',
#      u'kind': u'drive#permission',
#      u'role': u'reader',
#      u'type': u'group'},
#     {u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': True,
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailVersion': u'0',
#    u'trashed': True,
#    u'version': u'696518',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webViewLink': u'https://drive.google.com/drive/folders/0B9WTleJ1MzaYSVBuVzRyVUFQT0U',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': True,
#     u'canChangeCopyRequiresWriterPermission': True,
#     u'canChangeViewersCanCopyContent': True,
#     u'canComment': True,
#     u'canCopy': False,
#     u'canDelete': True,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': True,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': True,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': True,
#     u'canUntrash': True},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2017-03-20T11:30:33.214Z',
#    u'explicitlyTrashed': True,
#    u'folderColorRgb': u'#8f8f8f',
#    u'hasThumbnail': False,
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder',
#    u'id': u'0B9WTleJ1MzaYbFFLOHJjOVM5Rms',
#    u'isAppAuthorized': True,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Aaron Ciuffo',
#     u'emailAddress': u'aciuffo@ash.nl',
#     u'kind': u'drive#user',
#     u'me': True,
#     u'permissionId': u'14867985035974787748',
#     u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'},
#    u'mimeType': u'application/vnd.google-apps.folder',
#    u'modifiedByMe': True,
#    u'modifiedByMeTime': u'2017-03-20T11:30:33.214Z',
#    u'modifiedTime': u'2017-03-20T11:30:33.214Z',
#    u'name': u'Abohaimed, Saud - 503868',
#    u'ownedByMe': True,
#    u'owners': [{u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'kind': u'drive#user',
#      u'me': True,
#      u'permissionId': u'14867985035974787748',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'}],
#    u'parents': [u'0ANWTleJ1MzaYUk9PVA'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': False,
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailVersion': u'0',
#    u'trashed': True,
#    u'version': u'270669',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webViewLink': u'https://drive.google.com/drive/folders/0B9WTleJ1MzaYbFFLOHJjOVM5Rms',
#    u'writersCanShare': True},
#   {u'capabilities': {u'canAddChildren': True,
#     u'canChangeCopyRequiresWriterPermission': True,
#     u'canChangeViewersCanCopyContent': True,
#     u'canComment': True,
#     u'canCopy': False,
#     u'canDelete': True,
#     u'canDownload': True,
#     u'canEdit': True,
#     u'canListChildren': True,
#     u'canMoveItemIntoTeamDrive': False,
#     u'canReadRevisions': False,
#     u'canRemoveChildren': True,
#     u'canRename': True,
#     u'canShare': True,
#     u'canTrash': True,
#     u'canUntrash': True},
#    u'copyRequiresWriterPermission': False,
#    u'createdTime': u'2017-03-20T10:56:05.560Z',
#    u'explicitlyTrashed': True,
#    u'folderColorRgb': u'#8f8f8f',
#    u'hasThumbnail': False,
#    u'iconLink': u'https://drive-thirdparty.googleusercontent.com/16/type/application/vnd.google-apps.folder',
#    u'id': u'0B9WTleJ1MzaYcWxKTm9IR0xNLTQ',
#    u'isAppAuthorized': True,
#    u'kind': u'drive#file',
#    u'lastModifyingUser': {u'displayName': u'Aaron Ciuffo',
#     u'emailAddress': u'aciuffo@ash.nl',
#     u'kind': u'drive#user',
#     u'me': True,
#     u'permissionId': u'14867985035974787748',
#     u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'},
#    u'mimeType': u'application/vnd.google-apps.folder',
#    u'modifiedByMe': True,
#    u'modifiedByMeTime': u'2017-03-20T10:56:05.560Z',
#    u'modifiedTime': u'2017-03-20T10:56:05.560Z',
#    u'name': u'Abohaimed, Saud - 503868',
#    u'ownedByMe': True,
#    u'owners': [{u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'kind': u'drive#user',
#      u'me': True,
#      u'permissionId': u'14867985035974787748',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg'}],
#    u'parents': [u'0ANWTleJ1MzaYUk9PVA'],
#    u'permissions': [{u'deleted': False,
#      u'displayName': u'Aaron Ciuffo',
#      u'emailAddress': u'aciuffo@ash.nl',
#      u'id': u'14867985035974787748',
#      u'kind': u'drive#permission',
#      u'photoLink': u'https://lh3.googleusercontent.com/-h73ELuq3EPc/AAAAAAAAAAI/AAAAAAAAABg/USQhYvMjp5k/s64/photo.jpg',
#      u'role': u'owner',
#      u'type': u'user'}],
#    u'quotaBytesUsed': u'0',
#    u'shared': False,
#    u'spaces': [u'drive'],
#    u'starred': False,
#    u'thumbnailVersion': u'0',
#    u'trashed': True,
#    u'version': u'270582',
#    u'viewedByMe': False,
#    u'viewersCanCopyContent': True,
#    u'webViewLink': u'https://drive.google.com/drive/folders/0B9WTleJ1MzaYcWxKTm9IR0xNLTQ',
#    u'writersCanShare': True}]}

# %%
myDrive.search(name='Abohaimed', fuzzy=True, fields='webViewLink, id')
# Out:
# INFO:__main__:attempt: 0
# DEBUG:__main__:apicall: files().list(q=name contains "Abohaimed" and trashed=False, orderBy=createdTime, fields=files(webViewLink,id)))
# INFO:googleapiclient.discovery:URL being requested: GET https://www.googleapis.com/drive/v3/files?q=name+contains+%22Abohaimed%22+and+trashed%3DFalse&orderBy=createdTime&alt=json
# {u'files': [{u'id': u'0B7jrBr-B2fCedllGZWFvRWJpdEk',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/vnd.google-apps.folder',
#    u'name': u'Abohaimed, Saud - 503868'},
#   {u'id': u'0B76WmzZ8OsBPeFZLS0Rud0RLZVE',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed DRA Feb 2017.pdf'},
#   {u'id': u'0B76WmzZ8OsBPbDBBdWdLUDZCQ2s',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed Writing Sample June 2017.pdf'},
#   {u'id': u'0B0uxnCxt4-KAc2xQeGhoNV90VE0',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'iPad Guidelines - Saud Abohaimed'},
#   {u'id': u'0B0uxnCxt4-KAQnBEZ3pkT0tCTHM',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed - Happy Maps ASH.pdf'},
#   {u'id': u'0B0uxnCxt4-KAQzhSUlExS0F1cjQ',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed - Happy Maps ASH 2.pdf'},
#   {u'id': u'0B0uxnCxt4-KAYmdsWXMwRlJJVXc',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Edited - Saud Abohaimed - Happy Maps ASH 2.pdf'},
#   {u'id': u'0B9WTleJ1MzaYOC0yemd2RXdtalU',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_RC_Gr 1 Q4 2016-2017.pdf'},
#   {u'id': u'10bqyHqGQE3cnugWkGMd8HHOlEc7sHk2t',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_ASH EAL report card grade 2 S1 2017-18.pdf'},
#   {u'id': u'1GO89kVokPemNCeHKslnj25ErNhUGmQn6',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_ASH grade 2 EAL progress report S2 2017-18.pdf'},
#   {u'id': u'1wfitLtTBcgo0ES-8aX1lHUDCyaBGFaQ1',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_ASH grade 2 progress report 2017-18.pdf'},
#   {u'id': u'15FW8EFK7YiEMVoR1hzlnXUb7RgjKbIQz',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Abohaimed, Saud Progress Report Q3 2017-2018.pdf'},
#   {u'id': u'12Pdw_QREiiB5E0NTA9u_7-fIFRNSp3tb',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Abohaimed, Saud DRA Feb 2018.pdf'},
#   {u'id': u'1eBNmkYhGS4VaKzX6JZwWb5XxE5FH8qih',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Abohaimed, Saud Grade 2 MAP 2017-2018.pdf'},
#   {u'id': u'1LQoNe-MAHf9AJz_bKKuQdPB8knSUpllc',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf'},
#   {u'id': u'1iQDEgZuNK_RVvGcgz04WRhnAxaN4tSsn',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 EAL Report Card - S2 2017-18.pdf'},
#   {u'id': u'1Mr-Trcv2UAiV9a-6VmmaqrWeT1OuoRgm',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf'},
#   {u'id': u'1OczQw4RZWisch6SzfhfcAb5iXmv-Yf82',
#    u'kind': u'drive#file',
#    u'mimeType': u'application/pdf',
#    u'name': u'Saud Abohaimed-503868-1_grade 2 report card 2017-18 Q4.pdf'}],
#  u'incompleteSearch': False,
#  u'kind': u'drive#fileList'}
